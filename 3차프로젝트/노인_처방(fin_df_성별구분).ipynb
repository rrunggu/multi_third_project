# %%
# 필요 패키지 import
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
# matplotlib 한글처리


# matplotlib의 기본 폰트에서 한글 지원되지 않기 때문에
# matplotlib의 폰트 변경 필요
import platform

from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':  # 맥OS 
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':  # 윈도우
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system...  sorry~~~')

# %%
df = pd.read_csv('노인최종_fin.csv')
df
# Out:
#        Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  연령대  나이 나이구분 상장구분  신장(cm)  \
# 0               4             4               4   60  69   노인  3등급   143.5
# 1              28            28              28   70  74   노인  3등급   161.5
# 2              35            35              35   70  70   노인  3등급   172.0
# 3              36            36              36   70  76   노인  3등급   165.1
# 4              37            37              37   60  65   노인  2등급   155.0
# ...           ...           ...             ...  ...  ..  ...  ...     ...
# 41087      269921        269921          269921   60  65   노인  참가증   151.9
# 41088      269924        269924          269924   70  76   노인  참가증   157.7
# 41089      269946        269946          269946   70  72   노인  3등급   170.2
# 41090      269968        269968          269968   70  73   노인  참가증   154.8
# 41091      269985        269985          269985   70  77   노인  3등급   165.3
#
#        체중(kg)  체지방율(%)  ...  \
# 0        66.5     45.5  ...
# 1        58.9     20.2  ...
# 2        81.3     26.5  ...
# 3        68.7     30.1  ...
# 4        64.0     35.7  ...
# ...       ...      ...  ...
# 41087    59.0     35.9  ...
# 41088    58.8     34.8  ...
# 41089    70.5     20.4  ...
# 41090    47.8     29.1  ...
# 41091    63.2     27.6  ...
#
#                                                     운동루틴    측정일자  측정횟수  \
# 0      준비운동:짐볼 들고 양옆으로 돌리기,의자에 앉아 볼 돌리기,의자에 앉아 등 굽혔다 ...  201903     1
# 1      준비운동:누워서 전신 뻗기,깍지 끼고 상체 숙이기,양팔 벌려 전신 비틀기,고정식 트...  201903     3
# 2          본운동:옆구리 스트레칭,엉덩이 스트레칭,넙다리 뒤쪽 스트레칭,넙다리 안쪽 스트레칭  201903     1
# 3      본운동:엉덩이 스트레칭2,넙다리 안쪽 스트레칭,가슴 스트레칭,몸통 들어올리기,벽에서...  201903     1
# 4       준비운동:누워서 전신 뻗기,깍지 끼고 상체 숙이기 / 본운동:몸통 비틀기,어깨 스트레칭  201903     1
# ...                                                  ...     ...   ...
# 41087      본운동:걷기,물속에서 걷기,고정식 자전거 타기,고정식 트레드밀에서 걷기,아쿠아로빅  201911     1
# 41088  본운동:어깨 뒤쪽 스트레칭,아래 팔 스트레칭,양팔 벌려 전신 비틀기,엉덩이 스트레칭...  201911     1
# 41089  준비운동:하지 루틴 스트레칭1,상지 루틴 스트레칭 / 본운동:앉아서 덤벨로 손목 굽...  201911     1
# 41090  준비운동:유산소 운동 전 동적 루틴 스트레칭,골반 스트레칭,골반 스트레칭2,몸통 앞...  201911     3
# 41091  준비운동:덤벨 잡고 앉았다 일어서기,덤벨 잡고 뒤꿈치 들기,덤벨 잡고 한발 내밀어 ...  201911     1
#
#          센터이름  테스트형태  입력자  성별  \
# 0          부천     일반  관리자   F
# 1      동구(광주)     일반  관리자   M
# 2         의정부     일반  관리자   M
# 3         의정부     일반  관리자   M
# 4          부천     일반  관리자   F
# ...       ...    ...  ...  ..
# 41087      화성     출장  관리자   F
# 41088      화성     출장  관리자   F
# 41089      세종     일반  관리자   M
# 41090      성남     출장  관리자   F
# 41091      오산     일반  인바디   M
#
#                                                      본운동  \
# 0                   ['Aa016', 'Ad006', 'Ag018', 'Ag020']
# 1      ['Aa009', 'Aa021', 'Aa020', 'Ac004', 'Ad008', ...
# 2                   ['Bi025', 'Bd024', 'Ba059', 'Ba055']
# 3          ['Bd025', 'Ba055', 'Bi036', 'Ao002', 'Ah004']
# 4                                     ['Bi029', 'Bs016']
# ...                                                  ...
# 41087      ['Ce174', 'Ce188', 'Ce191', 'Ce192', 'Ce187']
# 41088  ['Bs025', 'Bl019', 'Be077', 'Bd025', 'Ba056', ...
# 41089                        ['Al006', 'Al005', 'Ah004']
# 41090  ['Ce188', 'Ce180', 'Ce170', 'Ce192', 'Ce191', ...
# 41091                                              ['N']
#
#                                                     준비운동  \
# 0                            ['Ae038', 'Al002', 'Ap001']
# 1                   ['Be079', 'Be078', 'Be077', 'Ce192']
# 2                                                  ['N']
# 3                                                  ['N']
# 4                                     ['Be079', 'Be078']
# ...                                                  ...
# 41087                                              ['N']
# 41088                                              ['N']
# 41089                                 ['Bq008', 'Bk011']
# 41090               ['Be084', 'Bi038', 'Ba046', 'Be076']
# 41091  ['Aq003', 'Ac004', 'Ad008', 'Ai007', 'Ao002', ...
#
#                                                    마무리운동
# 0                                              ['Ap001']
# 1      ['Be079', 'Be078', 'Ba056', 'Ba055', 'Bi025', ...
# 2                                                  ['N']
# 3                                                  ['N']
# 4                                                  ['N']
# ...                                                  ...
# 41087                                              ['N']
# 41088                                              ['N']
# 41089                                          ['Be085']
# 41090  ['Bq008', 'Bq007', 'Be085', 'Ba054', 'Ba053', ...
# 41091                                              ['N']
#
# [41092 rows x 56 columns]

# %%
feature_names = ['본운동','준비운동','마무리운동']
exer_df = pd.DataFrame(data=df,columns=feature_names)

# %%
exer_df.head(5)
exer_df.tail(5)
# Out:
#                                                  본운동  \
# 0               ['Aa016', 'Ad006', 'Ag018', 'Ag020']
# 1  ['Aa009', 'Aa021', 'Aa020', 'Ac004', 'Ad008', ...
# 2               ['Bi025', 'Bd024', 'Ba059', 'Ba055']
# 3      ['Bd025', 'Ba055', 'Bi036', 'Ao002', 'Ah004']
# 4                                 ['Bi029', 'Bs016']
#
#                                    준비운동  \
# 0           ['Ae038', 'Al002', 'Ap001']
# 1  ['Be079', 'Be078', 'Be077', 'Ce192']
# 2                                 ['N']
# 3                                 ['N']
# 4                    ['Be079', 'Be078']
#
#                                                마무리운동
# 0                                          ['Ap001']
# 1  ['Be079', 'Be078', 'Ba056', 'Ba055', 'Bi025', ...
# 2                                              ['N']
# 3                                              ['N']
# 4                                              ['N']
#                                                      본운동  \
# 41087      ['Ce174', 'Ce188', 'Ce191', 'Ce192', 'Ce187']
# 41088  ['Bs025', 'Bl019', 'Be077', 'Bd025', 'Ba056', ...
# 41089                        ['Al006', 'Al005', 'Ah004']
# 41090  ['Ce188', 'Ce180', 'Ce170', 'Ce192', 'Ce191', ...
# 41091                                              ['N']
#
#                                                     준비운동  \
# 41087                                              ['N']
# 41088                                              ['N']
# 41089                                 ['Bq008', 'Bk011']
# 41090               ['Be084', 'Bi038', 'Ba046', 'Be076']
# 41091  ['Aq003', 'Ac004', 'Ad008', 'Ai007', 'Ao002', ...
#
#                                                    마무리운동
# 41087                                              ['N']
# 41088                                              ['N']
# 41089                                          ['Be085']
# 41090  ['Bq008', 'Bq007', 'Be085', 'Ba054', 'Ba053', ...
# 41091                                              ['N']

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'Unnamed: 0.1.1', '연령대', '나이', '나이구분',
#        '상장구분', '신장(cm)', '체중(kg)', '체지방율(%)', '허리둘레(cm)', '이완기혈압(최저)',
#        '수축기혈압(최고)', '악력D(kg)', '악력ND(kg)', '윗몸말아올리기(회)', '반복점프(회)',
#        '앉아윗몸앞으로굽히기(cm)', '일리노이(초)', '체공시간(초)', '협응력시간(초)', '협응력실수횟수(회)',
#        '협응력계산결과값(초)', 'BMI(kg/㎡)', '교차윗몸일으키기(회)', '왕복오래달리기(회)',
#        '10M 4회 왕복달리기(초)', '제자리 멀리뛰기(cm)', '의자에앉았다일어서기(회)', '6분걷기(m)',
#        '2분제자리걷기(회)', '의자에앉아 3M표적 돌아오기(초)', '8자보행(초)', '상대악력(%)',
#        '왕복오래달리기(출력)(VO₂max)', '트레드밀_안정시(bpm)', '트레드밀_3분(bpm)', '트레드밀_6분(bpm)',
#        '트레드밀_9분(bpm)', '트레드밀(출력)(VO₂max)', '스텝검사_회복시 심박수(bpm)',
#        '스텝검사(출력)(VO₂max)', '허벅지(좌)', '허벅지(우)', '전신반응(초)', '체공시간(초).1', '운동루틴',
#        '측정일자', '측정횟수', '센터이름', '테스트형태', '입력자', '성별', '본운동', '준비운동', '마무리운동'],
#       dtype='object')

# %%
df.drop(['Unnamed: 0','Unnamed: 0.1','Unnamed: 0.1.1','측정횟수','센터이름','테스트형태','입력자','나이구분','상장구분','연령대',
              '허리둘레(cm)','윗몸말아올리기(회)','반복점프(회)','일리노이(초)','체공시간(초)','협응력시간(초)','협응력실수횟수(회)',
                       '협응력계산결과값(초)','교차윗몸일으키기(회)','왕복오래달리기(회)','10M 4회 왕복달리기(초)','제자리 멀리뛰기(cm)',
                       '왕복오래달리기(출력)(VO₂max)','트레드밀_안정시(bpm)','트레드밀_3분(bpm)','트레드밀_6분(bpm)','트레드밀_9분(bpm)',
                       '트레드밀(출력)(VO₂max)','스텝검사_회복시 심박수(bpm)','스텝검사(출력)(VO₂max)','허벅지(좌)','허벅지(우)',
                        '전신반응(초)','체공시간(초).1','6분걷기(m)','측정일자','본운동','준비운동','마무리운동','BMI(kg/㎡)',
                         '악력D(kg)','악력ND(kg)','운동루틴' ], axis=1,inplace=True)

# %%
df
# Out:
#        나이  신장(cm)  체중(kg)  체지방율(%)  이완기혈압(최저)  수축기혈압(최고)  앉아윗몸앞으로굽히기(cm)  \
# 0      69   143.5    66.5     45.5       67.0      182.0            16.1
# 1      74   161.5    58.9     20.2       89.0      137.0             3.1
# 2      70   172.0    81.3     26.5       70.0      120.0             0.7
# 3      76   165.1    68.7     30.1       78.0      151.0            10.8
# 4      65   155.0    64.0     35.7       87.0      130.0            15.2
# ...    ..     ...     ...      ...        ...        ...             ...
# 41087  65   151.9    59.0     35.9       72.0      133.0            27.0
# 41088  76   157.7    58.8     34.8       85.0      139.0             0.0
# 41089  72   170.2    70.5     20.4       80.0      127.0            26.3
# 41090  73   154.8    47.8     29.1       89.0      138.0             5.0
# 41091  77   165.3    63.2     27.6       74.0      136.0            -1.8
#
#        의자에앉았다일어서기(회)  2분제자리걷기(회)  의자에앉아 3M표적 돌아오기(초)  8자보행(초)  상대악력(%) 성별
# 0               26.0       131.0                5.90    23.24     36.3  F
# 1               25.0       107.0                5.29    22.94     66.0  M
# 2               32.0       122.0                4.53    19.47     54.9  M
# 3               22.0        94.0                5.03    22.30     43.9  M
# 4               23.0       110.0                5.93    21.05     40.4  F
# ...              ...         ...                 ...      ...      ... ..
# 41087           20.0        98.0                7.62     0.00     49.4  F
# 41088           13.0        90.0               10.19     0.00     38.0  F
# 41089           23.0       123.0                5.07    22.90     45.6  M
# 41090            5.0        57.0                9.28    32.57     34.1  F
# 41091           22.0       126.0                5.56    25.09     48.8  M
#
# [41092 rows x 13 columns]

# %%
df.isnull().sum()
# Out:
# 나이                       0
# 신장(cm)                   0
# 체중(kg)                   0
# 체지방율(%)                  1
# 이완기혈압(최저)                0
# 수축기혈압(최고)                0
# 앉아윗몸앞으로굽히기(cm)         128
# 의자에앉았다일어서기(회)          273
# 2분제자리걷기(회)            2452
# 의자에앉아 3M표적 돌아오기(초)     133
# 8자보행(초)                644
# 상대악력(%)                  9
# 성별                       0
# dtype: int64

# %%
df = df.dropna(subset=['체지방율(%)','의자에앉았다일어서기(회)','앉아윗몸앞으로굽히기(cm)','2분제자리걷기(회)',
                       '의자에앉아 3M표적 돌아오기(초)','8자보행(초)','상대악력(%)'])

# %%
df.isnull().sum()
# Out:
# 나이                    0
# 신장(cm)                0
# 체중(kg)                0
# 체지방율(%)               0
# 이완기혈압(최저)             0
# 수축기혈압(최고)             0
# 앉아윗몸앞으로굽히기(cm)        0
# 의자에앉았다일어서기(회)         0
# 2분제자리걷기(회)            0
# 의자에앉아 3M표적 돌아오기(초)    0
# 8자보행(초)               0
# 상대악력(%)               0
# 성별                    0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
le.fit(df.성별.unique())
df['성별'] = le.transform(df['성별'])
# Out:
# LabelEncoder()
# <ipython-input-12-20da1fce0289>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['성별'] = le.transform(df['성별'])

# %%
# 박스 플롯
plt.figure(figsize = (12,8))
for i in range(0,13):
    sns.boxplot(data = df[df.columns[i]],color = 'red' )
    plt.title(df.columns[i], size=15)
    plt.show()
# Out:
# <AxesSubplot:>
# Text(0.5, 1.0, '나이')
# <AxesSubplot:>
# Text(0.5, 1.0, '신장(cm)')
# <AxesSubplot:>
# Text(0.5, 1.0, '체중(kg)')
# <AxesSubplot:>
# Text(0.5, 1.0, '체지방율(%)')
# <AxesSubplot:>
# Text(0.5, 1.0, '이완기혈압(최저)')
# <AxesSubplot:>
# Text(0.5, 1.0, '수축기혈압(최고)')
# <AxesSubplot:>
# Text(0.5, 1.0, '앉아윗몸앞으로굽히기(cm)')
# <AxesSubplot:>
# Text(0.5, 1.0, '의자에앉았다일어서기(회)')
# <AxesSubplot:>
# Text(0.5, 1.0, '2분제자리걷기(회)')
# <AxesSubplot:>
# Text(0.5, 1.0, '의자에앉아 3M표적 돌아오기(초)')
# <AxesSubplot:>
# Text(0.5, 1.0, '8자보행(초)')
# <AxesSubplot:>
# Text(0.5, 1.0, '상대악력(%)')
# <AxesSubplot:>
# Text(0.5, 1.0, '성별')

# %%
df.describe()
# Out:
#                  나이        신장(cm)        체중(kg)       체지방율(%)     이완기혈압(최저)  \
# count  38048.000000  38048.000000  38048.000000  38048.000000  38048.000000
# mean      72.866642    157.111733     60.893862     31.994516     75.221786
# std        5.543339      8.246930      9.371611     20.960620     12.691537
# min       64.000000     65.000000     16.000000      0.000000      2.000000
# 25%       68.000000    151.000000     54.300000     26.600000     68.000000
# 50%       72.000000    156.100000     60.100000     32.500000     76.000000
# 75%       77.000000    163.000000     66.900000     37.300000     82.000000
# max      101.000000    191.400000    107.800000   3830.000000    900.000000
#
#           수축기혈압(최고)  앉아윗몸앞으로굽히기(cm)  의자에앉았다일어서기(회)    2분제자리걷기(회)  \
# count  38048.000000    38048.000000   38048.000000  38048.000000
# mean     133.279584        9.788641      19.687027    106.164844
# std       23.818469        9.850554       6.463610     26.185548
# min       10.000000      -30.000000       0.000000      0.000000
# 25%      122.000000        4.000000      15.000000     95.000000
# 50%      133.000000       10.800000      19.000000    109.000000
# 75%      144.000000       17.000000      24.000000    121.000000
# max     1988.000000      253.000000     101.000000    910.000000
#
#        의자에앉아 3M표적 돌아오기(초)       8자보행(초)       상대악력(%)            성별
# count        38048.000000  38048.000000  38048.000000  38048.000000
# mean             6.405065     26.254996     42.386690      0.363462
# std              1.837610      7.461754     11.222035      0.481003
# min              0.000000      0.000000      0.000000      0.000000
# 25%              5.280000     21.930000     35.000000      0.000000
# 50%              6.030000     25.200000     41.800000      0.000000
# 75%              7.070000     29.090000     49.300000      1.000000
# max             50.800000    157.700000    489.800000      1.000000

# %%
import numpy as np

def IQR_Rule(val_list):# 피처 한개에 대해 작업
    # IQR 계산
    Q1 = np.quantile(val_list,0.25)
    Q3 = np.quantile(val_list,0.75)
    
    IQR = Q3 - Q1 
    
    not_outlier_condition = (Q3 + 1.5 * IQR > val_list) & (Q1 - 1.5 * IQR < val_list)
    return not_outlier_condition

# %%
conditions = df.apply(IQR_Rule)
conditions
# Out:
#          나이  신장(cm)  체중(kg)  체지방율(%)  이완기혈압(최저)  수축기혈압(최고)  앉아윗몸앞으로굽히기(cm)  \
# 0      True    True    True     True       True      False            True
# 1      True    True    True     True       True       True            True
# 2      True    True    True     True       True       True            True
# 3      True    True    True     True       True       True            True
# 4      True    True    True     True       True       True            True
# ...     ...     ...     ...      ...        ...        ...             ...
# 41087  True    True    True     True       True       True            True
# 41088  True    True    True     True       True       True            True
# 41089  True    True    True     True       True       True            True
# 41090  True    True    True     True       True       True            True
# 41091  True    True    True     True       True       True            True
#
#        의자에앉았다일어서기(회)  2분제자리걷기(회)  의자에앉아 3M표적 돌아오기(초)  8자보행(초)  상대악력(%)    성별
# 0               True        True                True     True     True  True
# 1               True        True                True     True     True  True
# 2               True        True                True     True     True  True
# 3               True        True                True     True     True  True
# 4               True        True                True     True     True  True
# ...              ...         ...                 ...      ...      ...   ...
# 41087           True        True                True    False     True  True
# 41088           True        True               False    False     True  True
# 41089           True        True                True     True     True  True
# 41090           True        True                True     True     True  True
# 41091           True        True                True     True     True  True
#
# [38048 rows x 13 columns]

# %%
conditions.sum(axis=1) == len(df.columns)

# 이상치 제거 값 넣기
total_cond = conditions.sum(axis=1) == len(df.columns)

df1 = df.loc[total_cond]
# Out:
# 0        False
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 41087    False
# 41088    False
# 41089     True
# 41090     True
# 41091     True
# Length: 38048, dtype: bool

# %%
# 히스토 플롯
plt.figure(figsize = (12,8))
for i in range(0,13):
    sns.histplot(data = df1[df1.columns[i]] ,color = 'blue' )
    plt.title(df1.columns[i], size=15)
    plt.show()
# Out:
# <AxesSubplot:xlabel='나이', ylabel='Count'>
# Text(0.5, 1.0, '나이')
# <AxesSubplot:xlabel='신장(cm)', ylabel='Count'>
# Text(0.5, 1.0, '신장(cm)')
# <AxesSubplot:xlabel='체중(kg)', ylabel='Count'>
# Text(0.5, 1.0, '체중(kg)')
# <AxesSubplot:xlabel='체지방율(%)', ylabel='Count'>
# Text(0.5, 1.0, '체지방율(%)')
# <AxesSubplot:xlabel='이완기혈압(최저)', ylabel='Count'>
# Text(0.5, 1.0, '이완기혈압(최저)')
# <AxesSubplot:xlabel='수축기혈압(최고)', ylabel='Count'>
# Text(0.5, 1.0, '수축기혈압(최고)')
# <AxesSubplot:xlabel='앉아윗몸앞으로굽히기(cm)', ylabel='Count'>
# Text(0.5, 1.0, '앉아윗몸앞으로굽히기(cm)')
# <AxesSubplot:xlabel='의자에앉았다일어서기(회)', ylabel='Count'>
# Text(0.5, 1.0, '의자에앉았다일어서기(회)')
# <AxesSubplot:xlabel='2분제자리걷기(회)', ylabel='Count'>
# Text(0.5, 1.0, '2분제자리걷기(회)')
# <AxesSubplot:xlabel='의자에앉아 3M표적 돌아오기(초)', ylabel='Count'>
# Text(0.5, 1.0, '의자에앉아 3M표적 돌아오기(초)')
# <AxesSubplot:xlabel='8자보행(초)', ylabel='Count'>
# Text(0.5, 1.0, '8자보행(초)')
# <AxesSubplot:xlabel='상대악력(%)', ylabel='Count'>
# Text(0.5, 1.0, '상대악력(%)')
# <AxesSubplot:xlabel='성별', ylabel='Count'>
# Text(0.5, 1.0, '성별')

# %%
df1.describe()
# Out:
#                  나이        신장(cm)        체중(kg)       체지방율(%)     이완기혈압(최저)  \
# count  32402.000000  32402.000000  32402.000000  32402.000000  32402.000000
# mean      72.289828    157.281708     60.814603     31.754919     75.345886
# std        5.122442      7.964068      8.826097      7.369625      9.749697
# min       64.000000    133.200000     35.500000     10.600000     48.000000
# 25%       68.000000    151.300000     54.400000     26.500000     69.000000
# 50%       72.000000    156.300000     60.200000     32.300000     76.000000
# 75%       76.000000    163.000000     66.800000     37.000000     82.000000
# max       90.000000    180.900000     85.800000     53.000000    102.000000
#
#           수축기혈압(최고)  앉아윗몸앞으로굽히기(cm)  의자에앉았다일어서기(회)    2분제자리걷기(회)  \
# count  32402.000000    32402.000000   32402.000000  32402.000000
# mean     132.924690       10.583278      20.295722    110.340226
# std       14.780854        9.024949       5.875656     18.553151
# min       90.000000      -15.400000       2.000000     57.000000
# 25%      122.000000        4.800000      16.000000     99.000000
# 50%      132.000000       11.500000      20.000000    110.000000
# 75%      144.000000       17.300000      24.000000    122.000000
# max      176.000000       35.200000      37.000000    159.000000
#
#        의자에앉아 3M표적 돌아오기(초)       8자보행(초)       상대악력(%)            성별
# count        32402.000000  32402.000000  32402.000000  32402.000000
# mean             6.084335     25.307958     42.959728      0.359484
# std              1.153473      4.667507     10.075326      0.479857
# min              2.630000     11.280000     13.700000      0.000000
# 25%              5.230000     21.870000     35.900000      0.000000
# 50%              5.910000     24.830000     42.400000      0.000000
# 75%              6.790000     28.110000     49.700000      1.000000
# max              9.750000     39.810000     70.700000      1.000000

# %%
mat = np.zeros_like(df1.corr(method = 'pearson'))

# 상관관계 
plt.figure(figsize=(18,14))
sns.heatmap(df1.corr(method = 'pearson'),
            vmin = 0, vmax = +1, 
            annot = True, 
            cmap = 'RdYlBu_r', 
            linewidths=1,
            cbar_kws={"shrink": 0.4},
            mask = mat)
# Out:
# <AxesSubplot:>

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import scale
# 실루엣 분석 metric 값을 구하기 위한 API 추가
from sklearn.metrics import silhouette_samples, silhouette_score
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ##### 성별을 구분하여 작업

# %%
## 데이터 확인위해 DF로 변환_
df_1=pd.DataFrame(data=df1,columns=df1.columns)
df_1.head(3)
# Out:
#    나이  신장(cm)  체중(kg)  체지방율(%)  이완기혈압(최저)  수축기혈압(최고)  앉아윗몸앞으로굽히기(cm)  \
# 1  74   161.5    58.9     20.2       89.0      137.0             3.1
# 2  70   172.0    81.3     26.5       70.0      120.0             0.7
# 3  76   165.1    68.7     30.1       78.0      151.0            10.8
#
#    의자에앉았다일어서기(회)  2분제자리걷기(회)  의자에앉아 3M표적 돌아오기(초)  8자보행(초)  상대악력(%)  성별
# 1           25.0       107.0                5.29    22.94     66.0   1
# 2           32.0       122.0                4.53    19.47     54.9   1
# 3           22.0        94.0                5.03    22.30     43.9   1

# %%
df_1_f = df_1[df_1['성별']==0]
df_1_m = df_1[df_1['성별']==1]

# %%
df_1_f.drop(['성별'],axis=1, inplace=True)
df_1_m.drop(['성별'],axis=1, inplace = True)
# Out:
# C:\Users\82104\Anaconda3\lib\site-packages\pandas\core\frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
distortions = []
for k in range(2, 10):
    kmeans = KMeans(n_clusters=k)
    kmeans.fit(df_1_f)
    distortions.append(kmeans.inertia_)
fig = plt.figure(figsize=(10, 5))
plt.plot(range(2, 10), distortions)
plt.scatter(range(2, 10), distortions)
plt.grid(True)
plt.title('Elbow curve')
plt.show()
# Out:
# KMeans(n_clusters=2)
# KMeans(n_clusters=3)
# KMeans(n_clusters=4)
# KMeans(n_clusters=5)
# KMeans(n_clusters=6)
# KMeans(n_clusters=7)
# KMeans()
# KMeans(n_clusters=9)
# Text(0.5, 1.0, 'Elbow curve')

# %%
distortions = []
for k in range(2, 10):
    kmeans = KMeans(n_clusters=k)
    kmeans.fit(df_1_m)
    distortions.append(kmeans.inertia_)
fig = plt.figure(figsize=(10, 5))
plt.plot(range(2, 10), distortions)
plt.scatter(range(2, 10), distortions)
plt.grid(True)
plt.title('Elbow curve')
plt.show()
# Out:
# KMeans(n_clusters=2)
# KMeans(n_clusters=3)
# KMeans(n_clusters=4)
# KMeans(n_clusters=5)
# KMeans(n_clusters=6)
# KMeans(n_clusters=7)
# KMeans()
# KMeans(n_clusters=9)
# Text(0.5, 1.0, 'Elbow curve')

# %%
# KMeans(그룹 수, 초기 중심 설정 방식(디폴트:k-means++ or random), 최대 반복 횟수, 랜덤 스테이트)
kmeans_old_female = KMeans(n_clusters=4, init='k-means++', max_iter=300, random_state=0).fit(df_1_f) 

# labels_속성을 통해 각 데이터 포인트별로 할당된 군집 중심점을 확인
print(kmeans_old_female.labels_)

# 클러스터 라벨 값 입력
df_1_f['cluster']=kmeans_old_female.labels_
df_1_f
# Out:
# [3 2 3 ... 1 3 1]
# <ipython-input-27-8a5e20c00e09>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1_f['cluster']=kmeans_old_female.labels_
#        나이  신장(cm)  체중(kg)  체지방율(%)  이완기혈압(최저)  수축기혈압(최고)  앉아윗몸앞으로굽히기(cm)  \
# 4      65   155.0    64.0     35.7       87.0      130.0            15.2
# 5      67   149.9    59.0     34.5       78.0      133.0            17.3
# 8      66   156.8    63.6     32.7       86.0      155.0            30.0
# 13     77   153.6    68.1     41.1       70.0      130.0            14.5
# 14     76   140.1    54.2     42.6       80.0      120.0            15.0
# ...    ..     ...     ...      ...        ...        ...             ...
# 41070  77   150.0    49.8     29.1       69.0      155.0            16.8
# 41076  79   150.0    60.0     38.0       70.0      120.0             5.0
# 41078  75   158.0    65.2     30.3       66.0      132.0            21.9
# 41080  84   151.0    62.0     42.7       93.0      153.0            18.6
# 41090  73   154.8    47.8     29.1       89.0      138.0             5.0
#
#        의자에앉았다일어서기(회)  2분제자리걷기(회)  의자에앉아 3M표적 돌아오기(초)  8자보행(초)  상대악력(%)  \
# 4               23.0       110.0                5.93    21.05     40.4
# 5               35.0       149.0                4.88    17.66     39.8
# 8               19.0       110.0                4.82    21.12     35.2
# 13              18.0       102.0                5.68    24.22     38.6
# 14              28.0       100.0                5.87    29.56     42.8
# ...              ...         ...                 ...      ...      ...
# 41070           19.0        98.0                8.04    26.66     36.9
# 41076           25.0       116.0                6.90    32.00     14.6
# 41078           24.0        86.0                6.83    28.38     33.4
# 41080           17.0       103.0                7.52    30.65     28.0
# 41090            5.0        57.0                9.28    32.57     34.1
#
#        cluster
# 4            3
# 5            2
# 8            3
# 13           0
# 14           0
# ...        ...
# 41070        3
# 41076        0
# 41078        1
# 41080        3
# 41090        1
#
# [20754 rows x 13 columns]

# %%
# KMeans(그룹 수, 초기 중심 설정 방식(디폴트:k-means++ or random), 최대 반복 횟수, 랜덤 스테이트)
kmeans_old_male = KMeans(n_clusters=4, init='k-means++', max_iter=300, random_state=0).fit(df_1_m) 

# labels_속성을 통해 각 데이터 포인트별로 할당된 군집 중심점을 확인
print(kmeans_old_male.labels_)

# 클러스터 라벨 값 입력
df_1_m['cluster']=kmeans_old_male.labels_
df_1_m
# Out:
# [2 0 2 ... 2 0 3]
# <ipython-input-28-d11bee01db6a>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1_m['cluster']=kmeans_old_male.labels_
#        나이  신장(cm)  체중(kg)  체지방율(%)  이완기혈압(최저)  수축기혈압(최고)  앉아윗몸앞으로굽히기(cm)  \
# 1      74   161.5    58.9     20.2       89.0      137.0             3.1
# 2      70   172.0    81.3     26.5       70.0      120.0             0.7
# 3      76   165.1    68.7     30.1       78.0      151.0            10.8
# 7      66   167.0    69.1     20.1       74.0      121.0            24.5
# 10     68   159.1    57.4     26.2       96.0      148.0             6.5
# ...    ..     ...     ...      ...        ...        ...             ...
# 41071  71   158.0    63.1     25.5       70.0      145.0             7.0
# 41072  84   167.1    66.6     26.8       73.0      148.0             5.2
# 41086  66   165.0    72.5     28.4       91.0      153.0             3.7
# 41089  72   170.2    70.5     20.4       80.0      127.0            26.3
# 41091  77   165.3    63.2     27.6       74.0      136.0            -1.8
#
#        의자에앉았다일어서기(회)  2분제자리걷기(회)  의자에앉아 3M표적 돌아오기(초)  8자보행(초)  상대악력(%)  \
# 1               25.0       107.0                5.29    22.94     66.0
# 2               32.0       122.0                4.53    19.47     54.9
# 3               22.0        94.0                5.03    22.30     43.9
# 7               24.0       127.0                5.63    20.44     56.1
# 10              26.0        98.0                5.07    21.63     60.8
# ...              ...         ...                 ...      ...      ...
# 41071           18.0       102.0                5.94    23.93     54.1
# 41072           20.0        91.0                6.43    27.08     50.0
# 41086           21.0       102.0                4.03    18.03     61.2
# 41089           23.0       123.0                5.07    22.90     45.6
# 41091           22.0       126.0                5.56    25.09     48.8
#
#        cluster
# 1            2
# 2            0
# 3            2
# 7            0
# 10           2
# ...        ...
# 41071        2
# 41072        1
# 41086        2
# 41089        0
# 41091        3
#
# [11648 rows x 13 columns]

# %%
X_features = df_1_f[df_1_f.columns[:]].values
# 군집화 수행 : 군집 5개로 구성
kmeans = KMeans(n_clusters=4, random_state=0)
labels = kmeans.fit_predict(X_features)

# %%
y_features = df_1_m[df_1_m.columns[:]].values
# 군집화 수행 : 군집 5개로 구성
kmeans = KMeans(n_clusters=4, random_state=0)
labels = kmeans.fit_predict(y_features)

# %%
def visualize_silhouette(cluster_lists, X_features): 
    
    from sklearn.datasets import make_blobs
    from sklearn.cluster import KMeans
    from sklearn.metrics import silhouette_samples, silhouette_score

    import matplotlib.pyplot as plt
    import matplotlib.cm as cm
    import math
    
    # 입력값으로 클러스터링 갯수들을 리스트로 받아서, 각 갯수별로 클러스터링을 적용하고 실루엣 개수를 구함
    n_cols = len(cluster_lists)
    
    # plt.subplots()으로 리스트에 기재된 클러스터링 수만큼의 sub figures를 가지는 axs 생성 
    fig, axs = plt.subplots(figsize=(4*n_cols, 4), nrows=1, ncols=n_cols)
    
    # 리스트에 기재된 클러스터링 갯수들을 차례로 iteration 수행하면서 실루엣 개수 시각화
    for ind, n_cluster in enumerate(cluster_lists):
        
        # KMeans 클러스터링 수행하고, 실루엣 스코어와 개별 데이터의 실루엣 값 계산. 
        clusterer = KMeans(n_clusters = n_cluster, max_iter=500, random_state=0)
        cluster_labels = clusterer.fit_predict(X_features)
        
        sil_avg = silhouette_score(X_features, cluster_labels)
        sil_values = silhouette_samples(X_features, cluster_labels)
        
        y_lower = 10
        axs[ind].set_title('Number of Cluster : '+ str(n_cluster)+'\n' \
                          'Silhouette Score :' + str(round(sil_avg,3)) )
        axs[ind].set_xlabel("The silhouette coefficient values")
        axs[ind].set_ylabel("Cluster label")
        axs[ind].set_xlim([-0.1, 1])
        axs[ind].set_ylim([0, len(X_features) + (n_cluster + 1) * 10])
        axs[ind].set_yticks([])  # Clear the yaxis labels / ticks
        axs[ind].set_xticks([0, 0.2, 0.4, 0.6, 0.8, 1])
        
        # 클러스터링 갯수별로 fill_betweenx( )형태의 막대 그래프 표현. 
        for i in range(n_cluster):
            ith_cluster_sil_values = sil_values[cluster_labels==i]
            ith_cluster_sil_values.sort()
            
            size_cluster_i = ith_cluster_sil_values.shape[0]
            y_upper = y_lower + size_cluster_i
            
            color = cm.nipy_spectral(float(i) / n_cluster)
            axs[ind].fill_betweenx(np.arange(y_lower, y_upper), 0, ith_cluster_sil_values, \
                                facecolor=color, edgecolor=color, alpha=0.7)
            axs[ind].text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))
            y_lower = y_upper + 10
            
        axs[ind].axvline(x=sil_avg, color="red", linestyle="--")

# %%
def visualize_silhouette(cluster_lists, y_features): 
    
    from sklearn.datasets import make_blobs
    from sklearn.cluster import KMeans
    from sklearn.metrics import silhouette_samples, silhouette_score

    import matplotlib.pyplot as plt
    import matplotlib.cm as cm
    import math
    
    # 입력값으로 클러스터링 갯수들을 리스트로 받아서, 각 갯수별로 클러스터링을 적용하고 실루엣 개수를 구함
    n_cols = len(cluster_lists)
    
    # plt.subplots()으로 리스트에 기재된 클러스터링 수만큼의 sub figures를 가지는 axs 생성 
    fig, axs = plt.subplots(figsize=(4*n_cols, 4), nrows=1, ncols=n_cols)
    
    # 리스트에 기재된 클러스터링 갯수들을 차례로 iteration 수행하면서 실루엣 개수 시각화
    for ind, n_cluster in enumerate(cluster_lists):
        
        # KMeans 클러스터링 수행하고, 실루엣 스코어와 개별 데이터의 실루엣 값 계산. 
        clusterer = KMeans(n_clusters = n_cluster, max_iter=500, random_state=0)
        cluster_labels = clusterer.fit_predict(y_features)
        
        sil_avg = silhouette_score(y_features, cluster_labels)
        sil_values = silhouette_samples(y_features, cluster_labels)
        
        y_lower = 10
        axs[ind].set_title('Number of Cluster : '+ str(n_cluster)+'\n' \
                          'Silhouette Score :' + str(round(sil_avg,3)) )
        axs[ind].set_xlabel("The silhouette coefficient values")
        axs[ind].set_ylabel("Cluster label")
        axs[ind].set_xlim([-0.1, 1])
        axs[ind].set_ylim([0, len(y_features) + (n_cluster + 1) * 10])
        axs[ind].set_yticks([])  # Clear the yaxis labels / ticks
        axs[ind].set_xticks([0, 0.2, 0.4, 0.6, 0.8, 1])
        
        # 클러스터링 갯수별로 fill_betweenx( )형태의 막대 그래프 표현. 
        for i in range(n_cluster):
            ith_cluster_sil_values = sil_values[cluster_labels==i]
            ith_cluster_sil_values.sort()
            
            size_cluster_i = ith_cluster_sil_values.shape[0]
            y_upper = y_lower + size_cluster_i
            
            color = cm.nipy_spectral(float(i) / n_cluster)
            axs[ind].fill_betweenx(np.arange(y_lower, y_upper), 0, ith_cluster_sil_values, \
                                facecolor=color, edgecolor=color, alpha=0.7)
            axs[ind].text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))
            y_lower = y_upper + 10
            
        axs[ind].axvline(x=sil_avg, color="red", linestyle="--")

# %%
visualize_silhouette([ 3,4,5,6,7,8,9 ], X_features)

# %%
visualize_silhouette([ 3,4,5,6,7,8,9 ], y_features)

# %%
to_list = ['본운동', '준비운동', '마무리운동']

for j in to_list:
    for i in range(len(exer_df)):
        if exer_df[j][i] == "['N']":
            exer_df[j][i] = ''
        else:
            pass

# %%
abc = "[", "]" ,"'"
df_data = exer_df[['본운동','준비운동','마무리운동']]

for i in to_list :
    for k in abc :
        for j in range(len(df_data)) :
            df_data[i][j] = df_data[i][j].replace(k, '')

# %%
df_data['운동처방'] = df_data['준비운동'] + ',' + df_data['본운동'] + ',' + df_data['마무리운동']
df_data.drop(['본운동','마무리운동','준비운동'],axis=1,inplace=True)

# %%
df_data
# Out:
#                                                     운동처방
# 0      Ae038, Al002, Ap001,Aa016, Ad006, Ag018, Ag020...
# 1      Be079, Be078, Be077, Ce192,Aa009, Aa021, Aa020...
# 2                           ,Bi025, Bd024, Ba059, Ba055,
# 3                    ,Bd025, Ba055, Bi036, Ao002, Ah004,
# 4                             Be079, Be078,Bi029, Bs016,
# ...                                                  ...
# 41087                ,Ce174, Ce188, Ce191, Ce192, Ce187,
# 41088         ,Bs025, Bl019, Be077, Bd025, Ba056, Bd024,
# 41089             Bq008, Bk011,Al006, Al005, Ah004,Be085
# 41090  Be084, Bi038, Ba046, Be076,Ce188, Ce180, Ce170...
# 41091  Aq003, Ac004, Ad008, Ai007, Ao002, Ce192, Ce19...
#
# [41092 rows x 1 columns]

# %%
df_data = pd.DataFrame(df_data)


temp = []
for i in range(len(df_data)):
    temp.append(df_data['운동처방'][i].split(','))

df_data['운동처방1'] = temp

print(df_data)
# Out:
#                                                     운동처방  \
# 0      Ae038, Al002, Ap001,Aa016, Ad006, Ag018, Ag020...
# 1      Be079, Be078, Be077, Ce192,Aa009, Aa021, Aa020...
# 2                           ,Bi025, Bd024, Ba059, Ba055,
# 3                    ,Bd025, Ba055, Bi036, Ao002, Ah004,
# 4                             Be079, Be078,Bi029, Bs016,
# ...                                                  ...
# 41087                ,Ce174, Ce188, Ce191, Ce192, Ce187,
# 41088         ,Bs025, Bl019, Be077, Bd025, Ba056, Bd024,
# 41089             Bq008, Bk011,Al006, Al005, Ah004,Be085
# 41090  Be084, Bi038, Ba046, Be076,Ce188, Ce180, Ce170...
# 41091  Aq003, Ac004, Ad008, Ai007, Ao002, Ce192, Ce19...
#
#                                                    운동처방1
# 0      [Ae038,  Al002,  Ap001, Aa016,  Ad006,  Ag018,...
# 1      [Be079,  Be078,  Be077,  Ce192, Aa009,  Aa021,...
# 2                    [, Bi025,  Bd024,  Ba059,  Ba055, ]
# 3            [, Bd025,  Ba055,  Bi036,  Ao002,  Ah004, ]
# 4                       [Be079,  Be078, Bi029,  Bs016, ]
# ...                                                  ...
# 41087        [, Ce174,  Ce188,  Ce191,  Ce192,  Ce187, ]
# 41088  [, Bs025,  Bl019,  Be077,  Bd025,  Ba056,  Bd0...
# 41089      [Bq008,  Bk011, Al006,  Al005,  Ah004, Be085]
# 41090  [Be084,  Bi038,  Ba046,  Be076, Ce188,  Ce180,...
# 41091  [Aq003,  Ac004,  Ad008,  Ai007,  Ao002,  Ce192...
#
# [41092 rows x 2 columns]

# %%
result = df_data['운동처방'].str.split(',', expand=True)

temp = result.melt(var_name='col', value_name='index')

print(temp['index'].value_counts())
# Out:
#           42317
#  Bd024    10078
#  Ba055    10042
# Be085      7983
#  Ce191     7803
#           ...
# De130         1
# Bk009         1
#  Ce183        1
# Ap006         1
#  De135        1
# Name: index, Length: 716, dtype: int64

# %%
fin_df_f = df_1_f.join(df_data,how='inner')
fin_df_m = df_1_m.join(df_data,how='inner')

# %%
fin_df_f.head(5)
fin_df_m.head(5)
# Out:
#     나이  신장(cm)  체중(kg)  체지방율(%)  이완기혈압(최저)  수축기혈압(최고)  앉아윗몸앞으로굽히기(cm)  \
# 4   65   155.0    64.0     35.7       87.0      130.0            15.2
# 5   67   149.9    59.0     34.5       78.0      133.0            17.3
# 8   66   156.8    63.6     32.7       86.0      155.0            30.0
# 13  77   153.6    68.1     41.1       70.0      130.0            14.5
# 14  76   140.1    54.2     42.6       80.0      120.0            15.0
#
#     의자에앉았다일어서기(회)  2분제자리걷기(회)  의자에앉아 3M표적 돌아오기(초)  8자보행(초)  상대악력(%)  cluster  \
# 4            23.0       110.0                5.93    21.05     40.4        3
# 5            35.0       149.0                4.88    17.66     39.8        2
# 8            19.0       110.0                4.82    21.12     35.2        3
# 13           18.0       102.0                5.68    24.22     38.6        0
# 14           28.0       100.0                5.87    29.56     42.8        0
#
#                                                  운동처방  \
# 4                          Be079, Be078,Bi029, Bs016,
# 5   Be079, Be078, Br006, Bk010, Bs025, Bd024,Ce188...
# 8                        ,Al005, Al004, Al003, Ah004,
# 13  ,Ah003, Ak003, Ag016, Ag014, Ae014, Ae028, Ae0...
# 14                              ,Be073, Be072, Ae035,
#
#                                                 운동처방1
# 4                    [Be079,  Be078, Bi029,  Bs016, ]
# 5   [Be079,  Be078,  Br006,  Bk010,  Bs025,  Bd024...
# 8                 [, Al005,  Al004,  Al003,  Ah004, ]
# 13  [, Ah003,  Ak003,  Ag016,  Ag014,  Ae014,  Ae0...
# 14                        [, Be073,  Be072,  Ae035, ]
#     나이  신장(cm)  체중(kg)  체지방율(%)  이완기혈압(최저)  수축기혈압(최고)  앉아윗몸앞으로굽히기(cm)  \
# 1   74   161.5    58.9     20.2       89.0      137.0             3.1
# 2   70   172.0    81.3     26.5       70.0      120.0             0.7
# 3   76   165.1    68.7     30.1       78.0      151.0            10.8
# 7   66   167.0    69.1     20.1       74.0      121.0            24.5
# 10  68   159.1    57.4     26.2       96.0      148.0             6.5
#
#     의자에앉았다일어서기(회)  2분제자리걷기(회)  의자에앉아 3M표적 돌아오기(초)  8자보행(초)  상대악력(%)  cluster  \
# 1            25.0       107.0                5.29    22.94     66.0        2
# 2            32.0       122.0                4.53    19.47     54.9        0
# 3            22.0        94.0                5.03    22.30     43.9        2
# 7            24.0       127.0                5.63    20.44     56.1        0
# 10           26.0        98.0                5.07    21.63     60.8        2
#
#                                                  운동처방  \
# 1   Be079, Be078, Be077, Ce192,Aa009, Aa021, Aa020...
# 2                        ,Bi025, Bd024, Ba059, Ba055,
# 3                 ,Bd025, Ba055, Bi036, Ao002, Ah004,
# 7   ,Aq002, Aa009, Aa021, Aa020, Aq000, Ad007, Aa016,
# 10                                     Ce188, Ce190,,
#
#                                                 운동처방1
# 1   [Be079,  Be078,  Be077,  Ce192, Aa009,  Aa021,...
# 2                 [, Bi025,  Bd024,  Ba059,  Ba055, ]
# 3         [, Bd025,  Ba055,  Bi036,  Ao002,  Ah004, ]
# 7   [, Aq002,  Aa009,  Aa021,  Aa020,  Aq000,  Ad0...
# 10                                [Ce188,  Ce190, , ]

# %%
# 노인 남자 군집 4개
a1 = fin_df_m[fin_df_m['cluster']==0]
a2 = fin_df_m[fin_df_m['cluster']==1]
a3 = fin_df_m[fin_df_m['cluster']==2]
a4 = fin_df_m[fin_df_m['cluster']==3]
# 노인 여자 군집 4개
b1 = fin_df_f[fin_df_f['cluster']==0]
b2 = fin_df_f[fin_df_f['cluster']==1]
b3 = fin_df_f[fin_df_f['cluster']==2]
b4 = fin_df_f[fin_df_f['cluster']==3]

# %%
# 5점 척도 표현
# a1 = 상지 : 보통(3), 하지 : 보통(3), 심폐지구력 : 보통 이하(2) , 유연성 : 보통 이하(2) 평형성: 5 협응력 : 5
a1.describe()
# a2 = 상지 : 좋음(5), 하지 : 좋음(5), 심폐지구력 : 좋음(5) , 유연성 : 보통 이상(4) 평형성 4 협응력 2
a2.describe()
# a3 = 상지 : 보통 이상(4), 하지 : 보통 이상(4), 심폐지구력 : 보통 이상(4) , 유연성 : 보통(3) 평형성 : 4 협응력 :4 
a3.describe()
# a4 = 상지 : 보통 이상(4), 하지 : 좋음(5), 심폐지구력 : 보통 이상(4) , 유연성 : 보통 이상(4) 평형성 : 5 협응력 :5
a4.describe()
# Out:
#                 나이       신장(cm)       체중(kg)      체지방율(%)    이완기혈압(최저)  \
# count  3429.000000  3429.000000  3429.000000  3429.000000  3429.000000
# mean     72.690872   165.405658    65.234363    24.812218    70.048994
# std       4.963352     5.525471     7.939153     5.975571     8.647036
# min      65.000000   143.000000    37.400000    10.600000    48.000000
# 25%      69.000000   161.600000    59.900000    20.700000    64.000000
# 50%      72.000000   165.400000    65.100000    24.500000    70.000000
# 75%      76.000000   169.100000    70.600000    28.600000    77.000000
# max      89.000000   180.900000    85.700000    51.800000    99.000000
#
#          수축기혈압(최고)  앉아윗몸앞으로굽히기(cm)  의자에앉았다일어서기(회)   2분제자리걷기(회)  \
# count  3429.000000     3429.000000    3429.000000  3429.000000
# mean    120.885098        5.039592      22.151064   115.084281
# std       9.549978        8.614756       5.201308     9.893019
# min      90.000000      -15.400000       8.000000    86.000000
# 25%     115.000000       -0.800000      18.000000   108.000000
# 50%     121.000000        5.300000      22.000000   115.000000
# 75%     128.000000       11.000000      26.000000   121.000000
# max     142.000000       30.300000      37.000000   157.000000
#
#        의자에앉아 3M표적 돌아오기(초)      8자보행(초)      상대악력(%)  cluster
# count         3429.000000  3429.000000  3429.000000   3429.0
# mean             5.682158    24.037416    52.525314      0.0
# std              0.960025     3.959346     8.318658      0.0
# min              3.340000    11.280000    21.600000      0.0
# 25%              5.000000    21.130000    46.800000      0.0
# 50%              5.560000    23.750000    52.500000      0.0
# 75%              6.220000    26.400000    58.500000      0.0
# max              9.740000    39.750000    70.700000      0.0
#                 나이       신장(cm)       체중(kg)      체지방율(%)    이완기혈압(최저)  \
# count  2086.000000  2086.000000  2086.000000  2086.000000  2086.000000
# mean     75.784276   164.242905    66.147929    28.248530    73.395158
# std       5.222572     5.903910     8.597514     6.143864     9.194190
# min      65.000000   135.400000    40.440000    10.900000    48.000000
# 25%      72.000000   160.300000    59.940000    24.100000    67.000000
# 50%      76.000000   164.600000    66.300000    28.300000    74.000000
# 75%      79.000000   168.100000    72.200000    32.300000    80.000000
# max      90.000000   180.100000    85.800000    51.000000    99.000000
#
#          수축기혈압(최고)  앉아윗몸앞으로굽히기(cm)  의자에앉았다일어서기(회)   2분제자리걷기(회)  \
# count  2086.000000     2086.000000    2086.000000  2086.000000
# mean    131.127037        0.885168      16.791946    88.183126
# std      12.134208        8.209958       4.626257    11.085888
# min      90.000000      -15.400000       3.000000    57.000000
# 25%     123.000000       -5.300000      14.000000    81.000000
# 50%     131.000000        1.100000      16.000000    90.000000
# 75%     139.000000        6.500000      20.000000    97.000000
# max     166.000000       30.500000      35.000000   111.000000
#
#        의자에앉아 3M표적 돌아오기(초)      8자보행(초)      상대악력(%)  cluster
# count         2086.000000  2086.000000  2086.000000   2086.0
# mean             6.679438    28.501189    45.675551      1.0
# std              1.156257     4.562198     8.734911      0.0
# min              3.860000    15.510000    16.800000      1.0
# 25%              5.820000    25.182500    39.900000      1.0
# 50%              6.600000    28.170000    45.700000      1.0
# 75%              7.450000    31.527500    51.600000      1.0
# max              9.700000    39.760000    70.600000      1.0
#                 나이       신장(cm)       체중(kg)      체지방율(%)    이완기혈압(최저)  \
# count  3663.000000  3663.000000  3663.000000  3663.000000  3663.000000
# mean     73.415779   165.058886    67.375981    27.352735    81.024570
# std       4.971568     5.502864     8.076214     5.748470     9.124836
# min      65.000000   141.400000    39.700000    10.800000    50.000000
# 25%      70.000000   161.500000    62.000000    23.600000    75.000000
# 50%      73.000000   165.100000    67.400000    27.200000    81.000000
# 75%      77.000000   168.900000    72.850000    31.300000    88.000000
# max      90.000000   180.300000    85.800000    52.800000   102.000000
#
#          수축기혈압(최고)  앉아윗몸앞으로굽히기(cm)  의자에앉았다일어서기(회)  2분제자리걷기(회)  \
# count  3663.000000     3663.000000    3663.000000  3663.00000
# mean    147.994076        4.409716      20.933388   108.56047
# std       8.206343        8.185439       4.919498     8.67919
# min     128.000000      -15.300000       2.000000    81.00000
# 25%     141.000000       -0.500000      17.000000   102.00000
# 50%     149.000000        4.500000      21.000000   109.00000
# 75%     155.000000       10.000000      24.000000   115.00000
# max     176.000000       30.000000      37.000000   135.00000
#
#        의자에앉아 3M표적 돌아오기(초)      8자보행(초)      상대악력(%)  cluster
# count         3663.000000  3663.000000  3663.000000   3663.0
# mean             5.833081    24.461747    49.750259      2.0
# std              1.018495     4.216170     8.085837      0.0
# min              3.470000    14.800000    22.600000      2.0
# 25%              5.100000    21.450000    44.300000      2.0
# 50%              5.690000    23.870000    49.800000      2.0
# 75%              6.410000    26.800000    55.200000      2.0
# max              9.700000    39.790000    70.700000      2.0
#                 나이       신장(cm)       체중(kg)      체지방율(%)    이완기혈압(최저)  \
# count  2470.000000  2470.000000  2470.000000  2470.000000  2470.000000
# mean     71.350607   165.585101    66.905595    24.977302    79.312672
# std       4.599046     5.524521     7.491256     5.477690     9.045428
# min      65.000000   146.300000    41.400000    10.700000    48.000000
# 25%      67.000000   161.900000    61.800000    21.280303    73.000000
# 50%      71.000000   165.700000    67.000000    24.800000    79.000000
# 75%      75.000000   169.500000    72.100000    28.500000    86.000000
# max      90.000000   180.700000    85.800000    46.300000   101.000000
#
#          수축기혈압(최고)  앉아윗몸앞으로굽히기(cm)  의자에앉았다일어서기(회)   2분제자리걷기(회)  \
# count  2470.000000     2470.000000    2470.000000  2470.000000
# mean    141.796761        8.626628      26.524696   134.502429
# std      10.991362        7.690257       5.119076     9.503330
# min     108.000000      -15.200000       2.000000   115.000000
# 25%     134.000000        3.600000      23.000000   127.000000
# 50%     142.000000        8.600000      27.000000   133.000000
# 75%     151.000000       14.000000      30.000000   141.000000
# max     176.000000       33.000000      37.000000   159.000000
#
#        의자에앉아 3M표적 돌아오기(초)      8자보행(초)      상대악력(%)  cluster
# count         2470.000000  2470.000000  2470.000000   2470.0
# mean             5.059454    21.010607    54.241093      3.0
# std              0.748802     3.166169     7.387665      0.0
# min              3.050000    12.500000    17.600000      3.0
# 25%              4.560000    18.870000    49.200000      3.0
# 50%              4.990000    20.565000    54.300000      3.0
# 75%              5.480000    22.847500    59.600000      3.0
# max              9.500000    38.580000    70.600000      3.0

# %%
result = a1['운동처방'].str.split(',', expand=True)

temp = result.melt(var_name='col', value_name='index')

print(temp['index'].value_counts()[:20])
# Out:
#           3612
#  Bd024     792
#  Ba055     771
#  Bd025     651
#  Bp017     567
#  Ao002     540
# Be085      504
#  Bk010     502
#  Ah004     473
#  Bi025     467
#  Ce191     464
# Ce174      420
# Be079      409
#  Bq008     393
# Bd024      368
#  Bk011     349
#  Bq007     326
#  Ba056     325
#  Be078     320
#  Ae037     307
# Name: index, dtype: int64

# %%
result = a2['운동처방'].str.split(',', expand=True)

temp = result.melt(var_name='col', value_name='index')

print(temp['index'].value_counts()[:20])
# Out:
#           2194
#  Ce191     472
# Be085      452
#  Ba055     441
#  Ao002     412
#  Bd024     404
#  Ah004     348
#  Bd025     320
#  Ce192     300
#  Bp017     278
#  Bk010     267
#  Bi025     246
#  Bq007     237
# Be079      237
#  Ce170     225
#  Bk011     217
#  Ae037     216
#  Br006     211
#  Be078     207
#  Bq008     207
# Name: index, dtype: int64

# %%
result = a3['운동처방'].str.split(',', expand=True)

temp = result.melt(var_name='col', value_name='index')

print(temp['index'].value_counts()[:20])
# Out:
#           4174
#  Bd024     900
#  Ba055     823
#  Ce191     713
# Be085      672
#  Ao002     655
#  Bp017     608
#  Bk010     577
#  Bd025     550
#  Ah004     518
#  Bi025     498
#  Br006     458
#  Ce192     444
#  Bq007     434
#  Be078     426
# Be079      410
#  Ac004     410
#  Bq008     405
#  Ae037     392
#  Bk011     361
# Name: index, dtype: int64

# %%
result = a4['운동처방'].str.split(',', expand=True)

temp = result.melt(var_name='col', value_name='index')

print(temp['index'].value_counts()[:20])
# Out:
#           2787
#  Bd024     613
#  Ba055     587
#  Bp017     497
#  Bi025     458
#  Bk010     397
# Be085      388
#  Bd025     381
#  Ao002     368
#  Ah004     341
#  Bk011     307
#  Ce191     306
#  Bq008     297
# Be079      283
#  Ae037     269
#  Br006     255
#  Be078     248
#  Bl019     236
#  Ba059     233
#  Aa028     233
# Name: index, dtype: int64

# %%
# 5점 척도 표현
# b1 = 상지 : 보통(3), 하지 : 보통 이하(2), 심폐지구력 : 보통 이하(2) , 유연성 : 보통 이하(2)  평형성 : 4 협응력 : 4
b1.describe()
# b2 = 상지 : 좋음(5), 하지 : 좋음(5), 심폐지구력 : 좋음(5) , 유연성 : 보통 이상(4)  평형성 : 2 협응력 : 2
b2.describe()
# b3 = 상지 : 좋음(5), 하지 : 보통 이상(4), 심폐지구력 : 보통 이상(4) , 유연성 : 보통(3) 평형성 : 5  협응력 : 5
b3.describe()
# b4 = 상지 : 보통 이상(4), 하지 : 보통 이상(4), 심폐지구력 : 보통 이상(4) , 유연성 : 보통(3) 평형성 : 4 협응력 : 4
b4.describe()
# Out:
#                 나이       신장(cm)       체중(kg)      체지방율(%)    이완기혈압(최저)  \
# count  6173.000000  6173.000000  6173.000000  6173.000000  6173.000000
# mean     70.981208   153.326746    56.869323    33.835994    69.682002
# std       4.613124     5.158608     7.326833     6.090181     8.360428
# min      64.000000   133.400000    35.600000    10.800000    48.000000
# 25%      67.000000   150.000000    51.880000    30.100000    63.000000
# 50%      70.000000   153.200000    56.400000    34.300000    70.000000
# 75%      74.000000   156.800000    61.320000    37.800000    76.000000
# max      90.000000   176.700000    85.300000    52.400000    97.000000
#
#          수축기혈압(최고)  앉아윗몸앞으로굽히기(cm)  의자에앉았다일어서기(회)   2분제자리걷기(회)  \
# count  6173.000000     6173.000000    6173.000000  6173.000000
# mean    118.378422       14.010646      19.236838   109.511421
# std       8.919838        7.419614       4.824928     9.058377
# min      90.000000      -15.000000       3.000000    84.000000
# 25%     113.000000        9.400000      16.000000   102.000000
# 50%     120.000000       14.800000      19.000000   110.000000
# 75%     125.000000       19.400000      22.000000   116.000000
# max     140.000000       35.000000      36.000000   142.000000
#
#        의자에앉아 3M표적 돌아오기(초)      8자보행(초)      상대악력(%)  cluster
# count         6173.000000  6173.000000  6173.000000   6173.0
# mean             6.149837    25.660318    39.282407      0.0
# std              1.000770     4.006497     7.561226      0.0
# min              2.630000    11.600000    14.400000      0.0
# 25%              5.430000    22.820000    34.200000      0.0
# 50%              6.020000    25.400000    39.300000      0.0
# 75%              6.740000    27.940000    44.300000      0.0
# max              9.750000    39.800000    69.400000      0.0
#                 나이       신장(cm)       체중(kg)      체지방율(%)    이완기혈압(최저)  \
# count  4251.000000  4251.000000  4251.000000  4251.000000  4251.000000
# mean     74.268172   151.775206    58.025796    35.823160    74.777088
# std       5.484616     5.469957     8.043806     6.405273     8.875385
# min      65.000000   133.200000    35.500000    10.700000    48.000000
# 25%      70.000000   148.000000    52.620000    32.000000    69.000000
# 50%      74.000000   152.000000    57.400000    36.100000    76.000000
# 75%      78.000000   155.400000    63.300000    40.000000    80.000000
# max      90.000000   174.400000    85.600000    53.000000   100.000000
#
#          수축기혈압(최고)  앉아윗몸앞으로굽히기(cm)  의자에앉았다일어서기(회)   2분제자리걷기(회)  \
# count  4251.000000     4251.000000    4251.000000  4251.000000
# mean    131.053634       10.105954      15.291461    82.958127
# std      12.029784        7.647643       4.538615    10.331887
# min      90.000000      -15.000000       2.000000    57.000000
# 25%     122.000000        5.300000      12.000000    76.000000
# 50%     130.000000       10.500000      15.000000    85.000000
# 75%     139.000000       15.300000      18.000000    91.000000
# max     171.000000       33.000000      35.000000   105.000000
#
#        의자에앉아 3M표적 돌아오기(초)      8자보행(초)      상대악력(%)  cluster
# count         4251.000000  4251.000000  4251.000000   4251.0
# mean             7.128190    29.285088    34.574288      1.0
# std              1.134762     4.368116     7.942218      0.0
# min              3.550000    17.000000    13.700000      1.0
# 25%              6.300000    26.150000    29.300000      1.0
# 50%              7.100000    28.900000    34.600000      1.0
# 75%              7.940000    32.165000    39.800000      1.0
# max              9.750000    39.810000    70.600000      1.0
#                 나이       신장(cm)       체중(kg)      체지방율(%)    이완기혈압(최저)  \
# count  4487.000000  4487.000000  4487.000000  4487.000000  4487.000000
# mean     70.305772   153.334121    56.724150    33.594848    75.526632
# std       4.332494     4.949603     6.959574     5.765767     8.631074
# min      65.000000   135.600000    35.900000    10.700000    48.000000
# 25%      67.000000   150.000000    52.000000    30.100000    70.000000
# 50%      69.000000   153.400000    56.200000    33.900000    75.000000
# 75%      73.000000   156.600000    60.900000    37.300000    81.000000
# max      89.000000   175.900000    84.000000    51.700000   100.000000
#
#          수축기혈압(최고)  앉아윗몸앞으로굽히기(cm)  의자에앉았다일어서기(회)   2분제자리걷기(회)  \
# count  4487.000000     4487.000000    4487.000000  4487.000000
# mean    131.479831       16.873666      24.255627   133.592601
# std      11.762757        6.622544       5.411053     9.366364
# min      90.000000      -12.300000       2.000000   114.000000
# 25%     124.000000       13.000000      20.000000   126.000000
# 50%     131.000000       17.500000      24.000000   132.000000
# 75%     139.000000       21.400000      28.000000   140.000000
# max     166.000000       35.200000      37.000000   159.000000
#
#        의자에앉아 3M표적 돌아오기(초)      8자보행(초)      상대악력(%)  cluster
# count         4487.000000  4487.000000  4487.000000   4487.0
# mean             5.516640    22.658237    41.797593      2.0
# std              0.861916     3.518329     7.217104      0.0
# min              3.450000    14.530000    16.000000      2.0
# 25%              4.930000    20.240000    37.000000      2.0
# 50%              5.390000    22.140000    41.600000      2.0
# 75%              5.970000    24.555000    46.400000      2.0
# max              9.620000    39.350000    70.700000      2.0
#                 나이       신장(cm)       체중(kg)      체지방율(%)    이완기혈압(최저)  \
# count  5843.000000  5843.000000  5843.000000  5843.000000  5843.000000
# mean     71.964915   152.859267    58.966844    36.134591    80.172754
# std       4.971707     5.254429     7.773517     6.015289     8.710514
# min      65.000000   133.200000    36.500000    11.600000    50.000000
# 25%      68.000000   149.300000    53.370000    32.600000    74.000000
# 50%      71.000000   152.900000    58.500000    36.400000    80.000000
# 75%      75.000000   156.400000    63.900000    40.200000    86.000000
# max      90.000000   178.600000    85.800000    52.800000   102.000000
#
#          수축기혈압(최고)  앉아윗몸앞으로굽히기(cm)  의자에앉았다일어서기(회)   2분제자리걷기(회)  \
# count  5843.000000     5843.000000    5843.000000  5843.000000
# mean    145.273062       13.892064      19.143419   109.309088
# std       8.639392        7.190000       4.879405     9.526210
# min     123.000000      -15.000000       2.000000    80.000000
# 25%     138.000000        9.600000      16.000000   102.000000
# 50%     145.000000       14.400000      19.000000   109.000000
# 75%     152.000000       19.000000      22.000000   116.000000
# max     176.000000       33.000000      37.000000   139.000000
#
#        의자에앉아 3M표적 돌아오기(초)      8자보행(초)      상대악력(%)  cluster
# count          5843.00000  5843.000000  5843.000000   5843.0
# mean              6.30596    26.029702    38.228735      3.0
# std               1.05336     4.251621     7.542869      0.0
# min               3.57000    12.690000    13.800000      3.0
# 25%               5.54000    23.080000    33.350000      3.0
# 50%               6.18000    25.550000    38.000000      3.0
# 75%               6.93000    28.495000    42.900000      3.0
# max               9.75000    39.780000    70.600000      3.0

# %%
result = b1['운동처방'].str.split(',', expand=True)

temp = result.melt(var_name='col', value_name='index')

print(temp['index'].value_counts()[:20])
# Out:
#           5950
#  Bd024    1501
#  Ba055    1397
#  Bd025    1212
#  Ao002    1210
# Be085     1089
#  Bp017    1065
#  Bk010     953
#  Ah004     917
# Ce174      911
#  Ce191     890
#  Bi025     809
# Be079      808
# Bd024      703
#  Ba056     690
#  Bk011     671
#  Be078     653
#  Ae037     646
#  Ce192     610
#  Br006     605
# Name: index, dtype: int64

# %%
result = b2['운동처방'].str.split(',', expand=True)

temp = result.melt(var_name='col', value_name='index')

print(temp['index'].value_counts()[:20])
# Out:
#           4493
# Be085     1089
#  Ce191     866
#  Bd024     780
#  Ao002     741
#  Ba055     731
#  Bd025     699
#  Ce192     667
#  Ah004     634
# Be079      633
#  Be078     557
#  Bk010     554
#  Bp017     524
# Ce174      491
#  Be077     475
#  Ae037     469
#  Be085     453
#  Bk011     413
#  Bq007     402
#  Ba056     397
# Name: index, dtype: int64

# %%
result = b3['운동처방'].str.split(',', expand=True)

temp = result.melt(var_name='col', value_name='index')

print(temp['index'].value_counts()[:20])
# Out:
#           4272
#  Bd024    1357
#  Ba055    1256
#  Bp017    1123
#  Bi025    1095
#  Bk010     904
#  Bk011     761
#  Ao002     732
# Be079      688
# Be085      687
#  Bd025     667
#  Ah004     646
#  Ba056     580
#  Ae037     579
#  Be078     562
#  Ce191     556
# Bq008      537
#  Bs025     516
# Bd024      457
#  Br006     445
# Name: index, dtype: int64

# %%
result = b4['운동처방'].str.split(',', expand=True)

temp = result.melt(var_name='col', value_name='index')

print(temp['index'].value_counts()[:20])
# Out:
#           6066
#  Bd024    1556
#  Ba055    1489
# Be085     1155
#  Ao002    1142
#  Bp017    1116
#  Bk010    1116
#  Ce191    1006
#  Ah004    1006
# Be079      937
#  Bd025     930
#  Be078     853
#  Bi025     809
#  Br006     756
#  Bk011     708
#  Ce192     698
#  Ae037     694
#  Be077     693
#  Ba056     681
#  Bq007     632
# Name: index, dtype: int64
